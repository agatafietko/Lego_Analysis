# %%
import pandas as pd

df = pd.read_csv('lego_sets.csv')

theme = pd.read_csv('parent_themes.csv')

theme.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %% [markdown]
# ## 1) What % of all licensed sets ever released were Star Wars themed?

# %%
df.head()
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
theme.head()
# Out:
#     id     name  is_licensed
# 0    1  Technic        False
# 1   22  Creator        False
# 2   50     Town        False
# 3  112   Racers        False
# 4  126    Space        False

# %%
merged = df.merge(theme, left_on='parent_theme', right_on='name')
merged.drop(columns='name_y', inplace=True)
merged.head()
# Out:
#   set_num                      name_x  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme   id  is_licensed
# 0     Legoland  411        False
# 1         Town   50        False
# 2       Castle  186        False
# 3        Space  126        False
# 4        Space  126        False

# %%
merged[merged['set_num'].isnull()]
# Out:
#       set_num name_x  year  num_parts theme_name     parent_theme   id  \
# 11833     NaN    NaN  2017      347.0        NaN  Disney Princess  579
# 11834     NaN    NaN  2016       70.0        NaN  Disney Princess  579
# 11835     NaN    NaN  2016        NaN        NaN  Disney Princess  579
# 11836     NaN    NaN  2017      304.0        NaN     Super Heroes  482
# 11837     NaN    NaN  2017      196.0        NaN     Super Heroes  482
# ...       ...    ...   ...        ...        ...              ...  ...
# 11981     NaN    NaN  2014        NaN        NaN        Minecraft  577
# 11982     NaN    NaN  2006        NaN        NaN     Super Heroes  482
# 11983     NaN    NaN  2017        NaN        NaN        Minecraft  577
# 11984     NaN    NaN  2017        8.0        NaN     Super Heroes  482
# 11985     NaN    NaN  2003        NaN        NaN     Harry Potter  246
#
#        is_licensed
# 11833         True
# 11834         True
# 11835         True
# 11836         True
# 11837         True
# ...            ...
# 11981         True
# 11982         True
# 11983         True
# 11984         True
# 11985         True
#
# [153 rows x 8 columns]

# %%
licensed = merged[merged['is_licensed']]
licensed = licensed.dropna(subset=['set_num'])
licensed.head()


star_wars = licensed[licensed['parent_theme']== 'Star Wars']

the_force = ((star_wars.shape[0]/licensed.shape[0])*100)

print(the_force)
# Out:
# 51.653944020356235

# %% [markdown]
# ## Answer: 51.65%

# %% [markdown]
# # 2) In which year was Star Wars not the most popular licensed theme?

# %%
licensed_sorted = licensed.sort_values('year')

# %%
licensed_sorted['count'] = 1
licensed_sorted.head()
summed_df = licensed_sorted.groupby(['year', 'parent_theme']).sum().reset_index()

max_df = summed_df.sort_values('count', ascending=False).drop_duplicates(['year'])

max_df.sort_values('year', inplace=True)
max_df
# Out:
#     year  parent_theme                                            set_num  \
# 0   1999     Star Wars  7141-17150-17151-17131-17161-17130-17171-17128...
# 2   2000     Star Wars  7134-13341-1VP-87104-14151270-13343-13342-1712...
# 4   2001     Star Wars  7146-18008-1VP-28007-165028-165030-165034-1710...
# 6   2002     Star Wars  4195641-1K7153-1K7204-1K720x-18009-18010-18011...
# 9   2003     Star Wars  4481-14480-14479-14478-14476-14475-14207901-14...
# 12  2004     Star Wars  4501-2K10131-14502-24500-210134-14483-24495-14...
# 16  2005     Star Wars  K7283-16966-165771-16966-26965-265845-165844-1...
# 20  2006     Star Wars  7261-210175-110174-16205-16206-16207-16208-162...
# 24  2007     Star Wars  66221-17664-110179-110178-17665-17662-17654-17...
# 28  2008     Star Wars  20006-110186-18031-18029-18028-17668-17667-110...
# 32  2009     Star Wars  8016-18018-18019-166308-17752-17751-17749-1803...
# 36  2010     Star Wars  8095-18097-18089-18096-18099-18129-18091-18093...
# 42  2011     Star Wars  7929-17965-130053-17879-130054-17931-130052-17...
# 47  2012     Star Wars  celebvi-110227-166431-166432-19679-19678-19677...
# 52  2013     Star Wars  comcon032-1MAY2013-110236-110240-175000-175010...
# 59  2014     Star Wars  TRUXWINGTIE-130244-130246-130247-1TRUTIE-1TRUG...
# 67  2015     Star Wars  SDCC2015-2SW911506-1SW911508-1SW911509-1SW9115...
# 76  2016     Star Wars  75130-175131-175129-175126-175114-175115-17511...
# 82  2017  Super Heroes  5004930-15004929-1211701-141234-141233-170900-...
#
#                                                name_x  num_parts  \
# 0   Naboo FighterTIE Fighter & Y-wingSith Infiltra...     1384.0
# 2   A-wing FighterStar Wars #2 - Luke/Han/Boba Min...     2580.0
# 4   TIE FighterStormtrooper™Star Wars Co-Pack of 7...     2949.0
# 6   Star Wars Co-Pack of 7142 and 7152Episode II U...     4735.0
# 9   Hailfire DroidJabba's PalaceTIE BomberGeonosia...     6660.0
# 12  Mos Eisley Cantina, Original Trilogy Edition b...     1659.0
# 16  V-wing Space Battle CollectionJedi Starfighter...     4730.0
# 20  Clone Turbo Tank (with Non-Light-Up Mace Windu...     2769.0
# 24  X-wing Fighter and Luke Pilot Maquette Co-Pack...    11361.0
# 28  Clone Turbo Tank - MiniGeneral GrievousV-19 To...     6865.0
# 32  Hyena Droid BomberArmored Assault Tank (AAT)Re...     3953.0
# 36  General Grievous’ StarfighterSlave I (Third Ed...     6003.0
# 42  The Battle of NabooMillennium FalconRepublic A...     3451.0
# 47  Boba Fett’s Slave I - Mini - Star Wars Celebra...     6769.0
# 52  JEK-14 Mini Stealth Starfighter - San Diego Co...     6159.0
# 59  TRU X-Wing Fighter & TIE Fighter (May 3, 2014)...     8293.0
# 67  Dagobah Mini-BuildSnowspeederMini Slave 1Imper...    11410.0
# 76  AT-DPResistance Trooper Battle PackWookiee Gun...     6934.0
# 82  Accessory packBatman Battle PodBatmanBumblebee...    13123.0
#
#                                            theme_name     id  is_licensed  \
# 0   Star Wars Episode 1Star Wars Episode 4/5/6Star...   2054           13
# 2   Star Wars Episode 4/5/6Star Wars Episode 4/5/6...   4108           26
# 4   Star Wars Episode 4/5/6Star WarsStar Wars Epis...   2212           14
# 6   Star Wars Episode 4/5/6Star Wars Episode 2Star...   4424           28
# 9   Star WarsStar Wars Episode 4/5/6Star Wars Epis...   5056           32
# 12  Star Wars Episode 4/5/6Star Wars Episode 4/5/6...   3160           20
# 16  Star Wars Episode 3MiniStar Wars Episode 3Mini...   4424           28
# 20  Star Wars Episode 3Star Wars Episode 4/5/6Star...   1738           11
# 24  Star Wars Episode 4/5/6Star Wars OtherStar War...   2528           16
# 28  Star Wars Episode 3Star Wars Episode 3Star War...   3634           23
# 32  Star Wars Clone WarsStar Wars Clone WarsStar W...   6162           39
# 36  Star Wars Clone WarsStar Wars Episode 4/5/6Sta...   4740           30
# 42  Star Wars Episode 1Star Wars Episode 4/5/6Star...   5056           32
# 47  Star Wars Episode 4/5/6Star Wars Episode 4/5/6...   6794           43
# 52  Star WarsStar WarsStar Wars Episode 4/5/6Star ...   5530           35
# 59  Star Wars OtherMiniStar WarsStar WarsStar Wars...   7110           45
# 67  Star WarsStar Wars Episode 4/5/6MiniStar Wars ...   9164           58
# 76  Star Wars RebelsStar Wars Episode 7Star Wars R...   9638           61
# 82  BatmanBatmanBatmanSuper HeroesSuper HeroesBatm...  34704           72
#
#     count
# 0      13
# 2      26
# 4      14
# 6      28
# 9      32
# 12     20
# 16     28
# 20     11
# 24     16
# 28     23
# 32     39
# 36     30
# 42     32
# 47     43
# 52     35
# 59     45
# 67     58
# 76     61
# 82     72

# %%
new_era = 2017

# %% [markdown]
# ## Answer : 2017

# %% [markdown]
# ### 3) Break down number of sets by year

# %%
clean_df = merged[-merged['set_num'].isnull()]
clean_df['count'] = 1
sets_per_year = clean_df.groupby(['year']).sum().reset_index()[['year','count']]

for index,row in sets_per_year.iterrows():
    print(row['year'],row['count'])
# Out:
# 1950 7
# 1953 4
# 1954 14
# 1955 28
# 1956 12
# 1957 21
# 1958 42
# 1959 4
# 1960 3
# 1961 17
# 1962 40
# 1963 18
# 1964 11
# 1965 10
# 1966 89
# 1967 21
# 1968 25
# 1969 69
# 1970 29
# 1971 45
# 1972 38
# 1973 68
# 1974 39
# 1975 31
# 1976 68
# 1977 92
# 1978 73
# 1979 82
# 1980 88
# 1981 79
# 1982 76
# 1983 57
# 1984 76
# 1985 139
# 1986 123
# 1987 209
# 1988 68
# 1989 114
# 1990 85
# 1991 106
# 1992 115
# 1993 111
# 1994 128
# 1995 128
# 1996 144
# 1997 194
# 1998 325
# 1999 300
# 2000 327
# 2001 339
# 2002 447
# 2003 415
# 2004 371
# 2005 330
# 2006 283
# 2007 319
# 2008 349
# 2009 403
# 2010 444
# 2011 502
# 2012 615
# 2013 593
# 2014 715
# 2015 670
# 2016 608
# 2017 438
# /var/folders/cx/td960h412j76k6x1qhlfdhh40000gn/T/ipykernel_49172/3009026408.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['count'] = 1

# %% [markdown]
# ## How many of the sets each year were Star Wars theme?

# %%
star_wars_per_year = (
    clean_df[clean_df['parent_theme'] == 'Star Wars']
    .groupby(['year'])
    .size()
    .reset_index(name='star_wars_count')
)
result = pd.merge(sets_per_year, star_wars_per_year, on='year', how='left').fillna(0)

result['star_wars_count'] = result['star_wars_count'].astype(int)
result
# Out:
#     year  count  star_wars_count
# 0   1950      7                0
# 1   1953      4                0
# 2   1954     14                0
# 3   1955     28                0
# 4   1956     12                0
# ..   ...    ...              ...
# 61  2013    593               35
# 62  2014    715               45
# 63  2015    670               58
# 64  2016    608               61
# 65  2017    438               55
#
# [66 rows x 3 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import numpy as np

year = [year for year, df in clean_df.groupby('year')]
plt.bar(year, sets_per_year['count'])
plt.xticks(year, rotation='vertical', size=5)
plt.xticks(np.arange(1950,2017, step=5))
plt.ylabel('Numer of sets')
plt.xlabel('Year')
plt.show()

# %%
keys = result['year']
total_sets = result['count']
star_wars_sets = result['star_wars_count']

# %%
fig, ax1 = plt.subplots()
ax1.bar(keys, total_sets, color='g', alpha=0.7, label='Total Sets')
ax1.set_xlabel('Year')
ax1.set_ylabel('Number of Sets', color='g')
ax1.tick_params(axis='y', labelcolor='g')
ax1.set_xticks(keys)
ax1.set_xticklabels(keys, rotation='vertical', size=8)


ax2 = ax1.twinx()
ax2.plot(keys, star_wars_sets, 'b-', label='Star Wars Sets')
ax2.set_ylabel('Star Wars Count', color='b')
ax2.tick_params(axis='y', labelcolor='b')


plt.title('Total Sets and Star Wars Sets Per Year')
plt.xticks(np.arange(1950,2017, step=5))


plt.show()

# %% [markdown]
# ## We can see on the last graph how many of the sets each year were Star Wars, they are not a high % of all sets but still they were the most popular for many years!

# %%
result['star_wars_percentage'] = (result['star_wars_count'] / result['count']) * 100

star_wars_years = result[result['star_wars_count'] > 0]

star_wars_years.head(20)
# Out:
#     year  count  star_wars_count  star_wars_percentage
# 47  1999    300               13              4.333333
# 48  2000    327               26              7.951070
# 49  2001    339               14              4.129794
# 50  2002    447               28              6.263982
# 51  2003    415               32              7.710843
# 52  2004    371               20              5.390836
# 53  2005    330               28              8.484848
# 54  2006    283               11              3.886926
# 55  2007    319               16              5.015674
# 56  2008    349               23              6.590258
# 57  2009    403               39              9.677419
# 58  2010    444               30              6.756757
# 59  2011    502               32              6.374502
# 60  2012    615               43              6.991870
# 61  2013    593               35              5.902192
# 62  2014    715               45              6.293706
# 63  2015    670               58              8.656716
# 64  2016    608               61             10.032895
# 65  2017    438               55             12.557078
